# %%
import cv2
import imutils

def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))


# Cria duas variaveis globais
clicks = 0      # conta a quantidade de clicks dada
coordinates = []

# Função de callback, quando ocorre um evento do mouse, essa função é chamada
def mouse_click(event, x, y, flags, param):
    global clicks, frame
    # Se foi movimento do mouse  

    if clicks == 0:
        if event == cv2.EVENT_LBUTTONDOWN:
            #clicks += 1
            cv2.imshow('frame',frame)
            
    if clicks == 1:
        if event == cv2.EVENT_LBUTTONDOWN:
            
            #clicks += 1 
            frame = imutils.resize(frame, width=640)

            # Detecção dos rostos presentees no vídeo
            faces = face_cascade.detectMultiScale(frame, 1.3, 5)

            for (x, y, w, h) in faces:
                #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
                # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
                resized_image = imutils.resize(image, width=w)
                filas_image = resized_image.shape[0]
                col_image = w

                # Determinar uma porçãp do topo da imagemn de entrada redimensionada
                porcao_alto = filas_image // 4

                dif = 0

                # Si existe suficiente espacio sobre el rostro detectado
                # para insertar la imagen de entrada resimensionada
                # se visualizará dicha imagen
                if y + porcao_alto - filas_image >= 0:

                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
                else:
                    # Determinamos la sección de la imagen que excede a la del video
                    dif = abs(y + porcao_alto - filas_image) 
                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[0 : y + porcao_alto, x : x + col_image]

                # Determinamos la máscara que posee la imagen de entrada
                # redimensionada y también la invertimos
                mask = resized_image[:, :, 3]
                mask_inv = cv2.bitwise_not(mask)
            
                # Creamos una imagen con fondo negro y el gorro/tiara/2021
                # Luego creamos una imagen en donde en el fondo esté frame
                # y en negro el gorro/tiara/2021
                bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
                bg_black = bg_black[dif:, :, 0:3]
                bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

                # Sumamos las dos imágenes obtenidas
                result = cv2.add(bg_black, bg_frame)
                if y + porcao_alto - filas_image >= 0:
                    frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

                else:
                    frame[0 : y + porcao_alto, x : x + col_image] = result
    
    if clicks == 2:
        if event == cv2.EVENT_LBUTTONDOWN:
            #clicks += 1        
            detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

            for face in detections:
                x,y,w,h = face

                frame[y:y+h,x:x+w] = cv2.GaussianBlur(frame[y:y+h,x:x+w],(15,15),cv2.BORDER_DEFAULT)
            cv2.imshow('frame',frame)
                #cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)

                #cv2.imshow("output",frame)

            #k = cv2.waitKey(1) & 0xFF
            #if k == 27:
            #    break
    if clicks == 3:
        if event == cv2.EVENT_LBUTTONDOWN:
            #clicks += 1        
            detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

            for face in detections:
                x,y,w,h = face
        
                kernel = np.array([[-1, 0, -1], 
                           [-1, 11, -1], 
                           [-1, -1, -1]])
                # Realiza o produto de convolução
                frame[y:y+h,x:x+w] = cv2.filter2D(frame[y:y+h,x:x+w],-1,kernel)
            cv2.imshow('frame',frame)
    
    if clicks == 4:
        if event == cv2.EVENT_LBUTTONDOWN:
            cv2.imshow('frame',frame)
            clicks == 1
    else:
        if event == cv2.EVENT_RBUTTONDOWN:        
            cv2.imshow('frame',frame)

# Videostreaming o video de entrada
##cv2.VideoCapture("videoFiltro.mp4")
##cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
cap = cv2.VideoCapture("videoFiltro.mp4")

# Lectura de la imagen a incrustar en el video
#image = cv2.imread('gorro_navidad.png', cv2.IMREAD_UNCHANGED)
#image = cv2.imread('tiara.png', cv2.IMREAD_UNCHANGED)
image = cv2.imread('img/hat2.png', cv2.IMREAD_UNCHANGED)

# Detector de Rostos
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

while True:
    
    ret, frame = cap.read()
    if ret == False: break
    
    
    
    frame2 = cv2.setMouseCallback('frame', mouse_click)
    cv2.imshow('frame2',frame2)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [33], in <cell line: 135>()
#     137 ret, frame = cap.read()
#     138 if ret == False: break
# --> 142 frame2 = cv2.setMouseCallback('frame', mouse_click)
#     143 cv2.imshow('frame2',frame2)
#     145 k = cv2.waitKey(1) & 0xFF
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2563: error: (-27:Null pointer) NULL window: 'frame' in function 'cvSetMouseCallback'

# %%
import cv2
import imutils

def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))


# Cria duas variaveis globais
clicks = 0      # conta a quantidade de clicks dada
coordinates = []

# Função de callback, quando ocorre um evento do mouse, essa função é chamada
def mouse_click(event, x, y, flags, param):
    global clicks
    # Se foi movimento do mouse  
    
    if event == cv2.EVENT_LBUTTONDBLCLK:
            
        #clicks += 1 
        frame = imutils.resize(frame, width=640)

        # Detecção dos rostos presentees no vídeo
        faces = face_cascade.detectMultiScale(frame, 1.3, 5)

        for (x, y, w, h) in faces:
            #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
            # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
            resized_image = imutils.resize(image, width=w)
            filas_image = resized_image.shape[0]
            col_image = w

            # Determinar uma porçãp do topo da imagemn de entrada redimensionada
            porcao_alto = filas_image // 4

            dif = 0

            # Si existe suficiente espacio sobre el rostro detectado
            # para insertar la imagen de entrada resimensionada
            # se visualizará dicha imagen
            if y + porcao_alto - filas_image >= 0:

                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
            else:
                # Determinamos la sección de la imagen que excede a la del video
                dif = abs(y + porcao_alto - filas_image) 
                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[0 : y + porcao_alto, x : x + col_image]

            # Determinamos la máscara que posee la imagen de entrada
            # redimensionada y también la invertimos
            mask = resized_image[:, :, 3]
            mask_inv = cv2.bitwise_not(mask)
            
            # Creamos una imagen con fondo negro y el gorro/tiara/2021
            # Luego creamos una imagen en donde en el fondo esté frame
            # y en negro el gorro/tiara/2021
            bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
            bg_black = bg_black[dif:, :, 0:3]
            bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

            # Sumamos las dos imágenes obtenidas
            result = cv2.add(bg_black, bg_frame)
            if y + porcao_alto - filas_image >= 0:
                frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

            else:
                frame[0 : y + porcao_alto, x : x + col_image] = result
            cv2.imshow('frame',frame)
    else:
        cv2.imshow('frame',frame)

# Videostreaming o video de entrada
##cv2.VideoCapture("videoFiltro.mp4")
##cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
cap = cv2.VideoCapture("videoFiltro.mp4")

# Lectura de la imagen a incrustar en el video
#image = cv2.imread('gorro_navidad.png', cv2.IMREAD_UNCHANGED)
#image = cv2.imread('tiara.png', cv2.IMREAD_UNCHANGED)
image = cv2.imread('img/hat2.png', cv2.IMREAD_UNCHANGED)

# Detector de Rostos
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

while True:
    
    ret, frame = cap.read()
    if ret == False: break
    
    
    
    frame2 = cv2.setMouseCallback('frame', mouse_click)
    cv2.imshow('frame2',frame2)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [29], in <cell line: 92>()
#      94 ret, frame = cap.read()
#      95 if ret == False: break
# ---> 99 frame2 = cv2.setMouseCallback('frame', mouse_click)
#     100 cv2.imshow('frame2',frame2)
#     102 k = cv2.waitKey(1) & 0xFF
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2563: error: (-27:Null pointer) NULL window: 'frame' in function 'cvSetMouseCallback'

# %%
import cv2
import imutils

def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))


# Cria duas variaveis globais
clicks = 0      # conta a quantidade de clicks dada
coordinates = []

# Função de callback, quando ocorre um evento do mouse, essa função é chamada
def mouse_click(event, x, y, flags, param):
    global clicks, frame
    # Se foi movimento do mouse  
    frame = frame
    if event == cv2.EVENT_RBUTTONDOWN:
        clicks == 0
        frame = frame
        
    if event == cv2.EVENT_LBUTTONDOWN:    
        if clicks == 0:
            frame = frame
            
        if clicks == 1:
            frame = imutils.resize(frame, width=640)

            # Detecção dos rostos presentees no vídeo
            faces = face_cascade.detectMultiScale(frame, 1.3, 5)

            for (x, y, w, h) in faces:
                #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
                # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
                resized_image = imutils.resize(image, width=w)
                filas_image = resized_image.shape[0]
                col_image = w

                # Determinar uma porçãp do topo da imagemn de entrada redimensionada
                porcao_alto = filas_image // 4

                dif = 0

                # Si existe suficiente espacio sobre el rostro detectado
                # para insertar la imagen de entrada resimensionada
                # se visualizará dicha imagen
                if y + porcao_alto - filas_image >= 0:

                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
                else:
                    # Determinamos la sección de la imagen que excede a la del video
                    dif = abs(y + porcao_alto - filas_image) 
                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[0 : y + porcao_alto, x : x + col_image]

                # Determinamos la máscara que posee la imagen de entrada
                # redimensionada y también la invertimos
                mask = resized_image[:, :, 3]
                mask_inv = cv2.bitwise_not(mask)
            
                # Creamos una imagen con fondo negro y el gorro/tiara/2021
                # Luego creamos una imagen en donde en el fondo esté frame
                # y en negro el gorro/tiara/2021
                bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
                bg_black = bg_black[dif:, :, 0:3]
                bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

                # Sumamos las dos imágenes obtenidas
                result = cv2.add(bg_black, bg_frame)
                if y + porcao_alto - filas_image >= 0:
                    frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

                else:
                    frame[0 : y + porcao_alto, x : x + col_image] = result
            
        if clicks == 2:
            detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

            for face in detections:
                x,y,w,h = face

                frame[y:y+h,x:x+w] = cv2.GaussianBlur(frame[y:y+h,x:x+w],(15,15),cv2.BORDER_DEFAULT)
            
        if clicks == 3:
            #clicks += 1        
            detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

            for face in detections:
                x,y,w,h = face
        
                kernel = np.array([[-1, 0, -1], 
                           [-1, 11, -1], 
                           [-1, -1, -1]])
                # Realiza o produto de convolução
                frame[y:y+h,x:x+w] = cv2.filter2D(frame[y:y+h,x:x+w],-1,kernel) 
            
        if clicks == 4:
            clicks == 1
            frame = imutils.resize(frame, width=640)

            # Detecção dos rostos presentees no vídeo
            faces = face_cascade.detectMultiScale(frame, 1.3, 5)

            for (x, y, w, h) in faces:
                #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
                # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
                resized_image = imutils.resize(image, width=w)
                filas_image = resized_image.shape[0]
                col_image = w

                # Determinar uma porçãp do topo da imagemn de entrada redimensionada
                porcao_alto = filas_image // 4

                dif = 0

                # Si existe suficiente espacio sobre el rostro detectado
                # para insertar la imagen de entrada resimensionada
                # se visualizará dicha imagen
                if y + porcao_alto - filas_image >= 0:

                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
                else:
                    # Determinamos la sección de la imagen que excede a la del video
                    dif = abs(y + porcao_alto - filas_image) 
                    # Tomamos la sección de frame, en donde se va a ubicar
                    # el gorro/tiara
                    n_frame = frame[0 : y + porcao_alto, x : x + col_image]

                # Determinamos la máscara que posee la imagen de entrada
                # redimensionada y también la invertimos
                mask = resized_image[:, :, 3]
                mask_inv = cv2.bitwise_not(mask)
            
                # Creamos una imagen con fondo negro y el gorro/tiara/2021
                # Luego creamos una imagen en donde en el fondo esté frame
                # y en negro el gorro/tiara/2021
                bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
                bg_black = bg_black[dif:, :, 0:3]
                bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

                # Sumamos las dos imágenes obtenidas
                result = cv2.add(bg_black, bg_frame)
                if y + porcao_alto - filas_image >= 0:
                    frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

                else:
                    frame[0 : y + porcao_alto, x : x + col_image] = result
        
        else:
           frame = frame
    

# Videostreaming o video de entrada
##cv2.VideoCapture("videoFiltro.mp4")
##cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
cap = cv2.VideoCapture("videoFiltro.mp4")

# Lectura de la imagen a incrustar en el video
#image = cv2.imread('gorro_navidad.png', cv2.IMREAD_UNCHANGED)
#image = cv2.imread('tiara.png', cv2.IMREAD_UNCHANGED)
image = cv2.imread('img/hat2.png', cv2.IMREAD_UNCHANGED)

# Detector de Rostos
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
cv2.setMouseCallback('frame', mouse_click)
while True:
    
    ret, frame = cap.read()
    if ret == False: break
    
    
    
    cv2.imshow('frame2',frame2)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [37], in <cell line: 174>()
#     172 # Detector de Rostos
#     173 face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
# --> 174 cv2.setMouseCallback('frame', mouse_click)
#     175 while True:
#     177     ret, frame = cap.read()
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2563: error: (-27:Null pointer) NULL window: 'frame' in function 'cvSetMouseCallback'

# %%
import cv2
import imutils

def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))


# Cria duas variaveis globais
clicks = 0      # conta a quantidade de clicks dada
coordinates = []

# Função de callback, quando ocorre um evento do mouse, essa função é chamada


# Videostreaming o video de entrada
##cv2.VideoCapture("videoFiltro.mp4")
##cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
cap = cv2.VideoCapture("videoFiltro.mp4")

# Lectura de la imagen a incrustar en el video
#image = cv2.imread('gorro_navidad.png', cv2.IMREAD_UNCHANGED)
#image = cv2.imread('tiara.png', cv2.IMREAD_UNCHANGED)
image = cv2.imread('img/hat2.png', cv2.IMREAD_UNCHANGED)

# Detector de Rostos
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

# Função de callback, quando ocorre um evento do mouse, essa função é chamada
def mouse_click(event, x, y, flags, param):
    global clicks, cap
    # Se foi movimento do mouse
    ret, frame = cap.read()
    if event == cv2.EVENT_RBUTTONDOWN:
        clicks == 0
        frame = frame
        
    if event == cv2.EVENT_LBUTTONDOWN:    
        frame = imutils.resize(frame, width=640)

        # Detecção dos rostos presentees no vídeo
        faces = face_cascade.detectMultiScale(frame, 1.3, 5)

        for (x, y, w, h) in faces:
            #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
            # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
            resized_image = imutils.resize(image, width=w)
            filas_image = resized_image.shape[0]
            col_image = w

            # Determinar uma porçãp do topo da imagemn de entrada redimensionada
            porcao_alto = filas_image // 4

            dif = 0

            # Si existe suficiente espacio sobre el rostro detectado
            # para insertar la imagen de entrada resimensionada
            # se visualizará dicha imagen
            if y + porcao_alto - filas_image >= 0:

                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
            else:
                # Determinamos la sección de la imagen que excede a la del video
                dif = abs(y + porcao_alto - filas_image) 
                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[0 : y + porcao_alto, x : x + col_image]

            # Determinamos la máscara que posee la imagen de entrada
            # redimensionada y también la invertimos
            mask = resized_image[:, :, 3]
            mask_inv = cv2.bitwise_not(mask)
            
            # Creamos una imagen con fondo negro y el gorro/tiara/2021
            # Luego creamos una imagen en donde en el fondo esté frame
            # y en negro el gorro/tiara/2021
            bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
            bg_black = bg_black[dif:, :, 0:3]
            bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

            # Sumamos las dos imágenes obtenidas
            result = cv2.add(bg_black, bg_frame)
            if y + porcao_alto - filas_image >= 0:
                frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

            else:
                frame[0 : y + porcao_alto, x : x + col_image] = result
                
cv2.setMouseCallback('frame', mouse_click)
while True:
    
    #ret, frame = cap.read()
    if ret == False: break
    
    
    
    #cv2.setMouseCallback('frame', mouse_click)
    
    cv2.imshow('frame2',frame)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [3], in <cell line: 94>()
#      91             else:
#      92                 frame[0 : y + porcao_alto, x : x + col_image] = result
# ---> 94 cv2.setMouseCallback('frame', mouse_click)
#      95 while True:
#      96
#      97     #ret, frame = cap.read()
#      98     if ret == False: break
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2563: error: (-27:Null pointer) NULL window: 'frame' in function 'cvSetMouseCallback'

# %%
# Função de callback, quando ocorre um evento do mouse, essa função é chamada
def mouse_click(event, x, y, flags, param):
    global clicks
    # Se foi movimento do mouse  
    if event == cv2.EVENT_RBUTTONDOWN:
        clicks == 0
        frame = frame
        
    if event == cv2.EVENT_LBUTTONDOWN:    
        frame = imutils.resize(frame, width=640)

        # Detecção dos rostos presentees no vídeo
        faces = face_cascade.detectMultiScale(frame, 1.3, 5)

        for (x, y, w, h) in faces:
            #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
            # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
            resized_image = imutils.resize(image, width=w)
            filas_image = resized_image.shape[0]
            col_image = w

            # Determinar uma porçãp do topo da imagemn de entrada redimensionada
            porcao_alto = filas_image // 4

            dif = 0

            # Si existe suficiente espacio sobre el rostro detectado
            # para insertar la imagen de entrada resimensionada
            # se visualizará dicha imagen
            if y + porcao_alto - filas_image >= 0:

                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
            else:
                # Determinamos la sección de la imagen que excede a la del video
                dif = abs(y + porcao_alto - filas_image) 
                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[0 : y + porcao_alto, x : x + col_image]

            # Determinamos la máscara que posee la imagen de entrada
            # redimensionada y también la invertimos
            mask = resized_image[:, :, 3]
            mask_inv = cv2.bitwise_not(mask)
            
            # Creamos una imagen con fondo negro y el gorro/tiara/2021
            # Luego creamos una imagen en donde en el fondo esté frame
            # y en negro el gorro/tiara/2021
            bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
            bg_black = bg_black[dif:, :, 0:3]
            bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

            # Sumamos las dos imágenes obtenidas
            result = cv2.add(bg_black, bg_frame)
            if y + porcao_alto - filas_image >= 0:
                frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

            else:
                frame[0 : y + porcao_alto, x : x + col_image] = result

# %%
def mouse_click(event, x, y, flags, userdata):
    '''
    This function will draw circle and rectangle on a canvas and clear it based 
    on different mouse events.
    Args:
        event:    The mouse event that is captured.
        x:        The x-coordinate of the mouse pointer position on the window.
        y:        The y-coordinate of the mouse pointer position on the window.
        flags:    It is one of the MouseEventFlags constants.
        userdata: The parameter passed from the `cv2.setMouseCallback()` function.
    '''
    
    # Access the canvas from outside of the current scope.
    global clicks, teste
    
    # Check if the left mouse button is pressed.
    if event == cv2.EVENT_LBUTTONDOWN:
        if teste >= 3:
            teste = 1
            print(teste)
        else:
            teste += 1
            print(teste)
        
    elif event == cv2.EVENT_RBUTTONDOWN:
        teste = 0
        print(teste)

# %%
#def mouse_click(event, x, y, flags, userdata):
#    print(event)

# %%
import cv2
import imutils
import numpy as np

def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))


# Cria duas variaveis globais
clicks = 0      # conta a quantidade de clicks dada
##coordinates = []

def mouse_click(event, x, y, flags, userdata):

    global clicks
    
    if event == cv2.EVENT_LBUTTONDOWN:
        if clicks >= 3:
            clicks = 1
            print(clicks)
        else:
            clicks += 1
            print(clicks)
        
    elif event == cv2.EVENT_RBUTTONDOWN:
        clicks = 0
        print(clicks)
    

##cv2.VideoCapture("videoFiltro.mp4")
##cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
cap = cv2.VideoCapture("videoFiltro.mp4")

image = cv2.imread('img/hat.png', cv2.IMREAD_UNCHANGED)

face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

cv2.namedWindow('Frame')

cv2.setMouseCallback('Frame', mouse_click)
while True:
    
    ret, frame = cap.read()
    if ret == False: break
    
    if clicks == 1:
        ret, frame = cap.read()
        frame = imutils.resize(frame, width=640)

        faces = face_cascade.detectMultiScale(frame, 1.3, 5)

        for (x, y, w, h) in faces:

            resized_image = imutils.resize(image, width=w)
            filas_image = resized_image.shape[0]
            col_image = w

            porcao_alto = filas_image // 4

            dif = 0

            if y + porcao_alto - filas_image >= 0:
                n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
            else:
                dif = abs(y + porcao_alto - filas_image) 
               
                n_frame = frame[0 : y + porcao_alto, x : x + col_image]

            mask = resized_image[:, :, 3]
            mask_inv = cv2.bitwise_not(mask)
            
            bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
            bg_black = bg_black[dif:, :, 0:3]
            bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

            result = cv2.add(bg_black, bg_frame)
            if y + porcao_alto - filas_image >= 0:
                frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result
            else:
                frame[0 : y + porcao_alto, x : x + col_image] = result
    elif clicks == 2:
        ret ,frame = cap.read()
        frame = resize(frame)
        detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

        for face in detections:
            x,y,w,h = face

            frame[y:y+h,x:x+w] = cv2.GaussianBlur(frame[y:y+h,x:x+w],(15,15),cv2.BORDER_DEFAULT)
        
    elif clicks == 3:
        ret ,frame = cap.read()
        frame = resize(frame)
        detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

        for face in detections:
            x,y,w,h = face
        
            kernel = np.array([[-1, 0, -1], 
                   [-1, 11, -1], 
                   [-1, -1, -1]])
            # Realiza o produto de convolução
            frame[y:y+h,x:x+w] = cv2.filter2D(frame[y:y+h,x:x+w],-1,kernel)

    elif clicks == 0:
        ret, frame = cap.read()
    
    
    cv2.imshow('Frame', frame)

    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1
# 2
# 0
# 1
# 2
# 3
# 1
# 0

# %%
if teste == 1 or teste == 5:
        ret, frame = cap.read()
        frame = imutils.resize(frame, width=640)

        # Detecção dos rostos presentees no vídeo
        faces = face_cascade.detectMultiScale(frame, 1.3, 5)

        for (x, y, w, h) in faces:
            #cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0),2)
 
            # Redimensionar a imagem de entrada de acordo com a largura do rosto detectado
            resized_image = imutils.resize(image, width=w)
            filas_image = resized_image.shape[0]
            col_image = w

            # Determinar uma porçãp do topo da imagemn de entrada redimensionada
            porcao_alto = filas_image // 4

            dif = 0

            # Si existe suficiente espacio sobre el rostro detectado
            # para insertar la imagen de entrada resimensionada
            # se visualizará dicha imagen
            if y + porcao_alto - filas_image >= 0:

                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image]
            else:
                # Determinamos la sección de la imagen que excede a la del video
                dif = abs(y + porcao_alto - filas_image) 
                # Tomamos la sección de frame, en donde se va a ubicar
                # el gorro/tiara
                n_frame = frame[0 : y + porcao_alto, x : x + col_image]

            # Determinamos la máscara que posee la imagen de entrada
            # redimensionada y también la invertimos
            mask = resized_image[:, :, 3]
            mask_inv = cv2.bitwise_not(mask)
            
            # Creamos una imagen con fondo negro y el gorro/tiara/2021
            # Luego creamos una imagen en donde en el fondo esté frame
            # y en negro el gorro/tiara/2021
            bg_black = cv2.bitwise_and(resized_image, resized_image, mask=mask)
            bg_black = bg_black[dif:, :, 0:3]
            bg_frame = cv2.bitwise_and(n_frame, n_frame, mask=mask_inv[dif:,:])

            # Sumamos las dos imágenes obtenidas
            result = cv2.add(bg_black, bg_frame)
            if y + porcao_alto - filas_image >= 0:
                frame[y + porcao_alto - filas_image : y + porcao_alto, x : x + col_image] = result

            else:
                frame[0 : y + porcao_alto, x : x + col_image] = result
    elif teste == 2:
        ret ,frame = cap.read()
        frame = resize(frame)
        detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

        for face in detections:
            x,y,w,h = face

            frame[y:y+h,x:x+w] = cv2.GaussianBlur(frame[y:y+h,x:x+w],(15,15),cv2.BORDER_DEFAULT)
            #cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        
    elif teste == 3:
        ret ,frame = cap.read()
        frame = resize(frame)
        detections = face_cascade.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=6)

        for face in detections:
            x,y,w,h = face
        
            kernel = np.array([[-1, 0, -1], 
                   [-1, 11, -1], 
                   [-1, -1, -1]])
            # Realiza o produto de convolução
            frame[y:y+h,x:x+w] = cv2.filter2D(frame[y:y+h,x:x+w],-1,kernel)

    elif teste == 4 or teste == 0:
        ret, frame = cap.read()
# Out:
#   File <tokenize>:55
#     elif teste == 2:
#     ^
# IndentationError: unindent does not match any outer indentation level
